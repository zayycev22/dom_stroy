# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("files/times.csv")
df
# Out:
#        obj_key  obj_subprg Кодзадачи  ДатаНачалаЗадачи  Статуспоэкспертизе  \
# 0     017-0520           1         1            736999                   0
# 1     017-0520           1     1.4.2            738139                   0
# 2     017-0520           1         3            737841                   0
# 3     017-0520           1       3.1            737841                   0
# 4     017-0520           1      3.11            737900                   0
# ...        ...         ...       ...               ...                 ...
# 1840  022-0631           3      5.11            739160                   0
# 1841  022-0631           3       7.1            739160                   0
# 1842  022-0631           3     7.1.8            739201                   0
# 1843  022-0631           3       7.4            739202                   0
# 1844  022-0631           3         8            739222                   0
#
# ...

# %%
sns.scatterplot(df, x = "obj_key", y = "y")
# Out:
# <Axes: xlabel='obj_key', ylabel='y'>

# %%
sns.scatterplot(df, x = "obj_subprg", y = "y")
# Out:
# <Axes: xlabel='obj_subprg', ylabel='y'>

# %%
sns.scatterplot(df, x = "Кодзадачи", y = "y")
# Out:
# <Axes: xlabel='Кодзадачи', ylabel='y'>

# %%
sns.scatterplot(df, x = "ДатаНачалаЗадачи", y = "y")
# Out:
# <Axes: xlabel='ДатаНачалаЗадачи', ylabel='y'>

# %%
sns.scatterplot(df, x="Статуспоэкспертизе", y="y")
# Out:
# <Axes: xlabel='Статуспоэкспертизе', ylabel='y'>

# %%
sns.scatterplot(df, x="season", y="y")
# Out:
# <Axes: xlabel='season', ylabel='y'>

# %%
sns.scatterplot(df, x="Скорость", y="y")
# Out:
# <Axes: xlabel='Скорость', ylabel='y'>

# %%
sns.scatterplot(df, x="Кол-во рабочих", y="y")
# Out:
# <Axes: xlabel='Кол-во рабочих', ylabel='y'>

# %%
sns.scatterplot(df, x="Генподрядчик", y="y")
# Out:
# <Axes: xlabel='Генподрядчик', ylabel='y'>

# %%
sns.scatterplot(df, x="Генпроектировщик", y="y")
# Out:
# <Axes: xlabel='Генпроектировщик', ylabel='y'>

# %%
sns.scatterplot(df, x="Площадь", y="y")
# Out:
# <Axes: xlabel='Площадь', ylabel='y'>
